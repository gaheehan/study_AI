# %% [markdown]
# <a href="https://colab.research.google.com/github/gaheehan/study_AI/blob/main/%ED%9A%8C%EA%B8%B0(Regression).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 회귀(Regression)

# %% [markdown]
# ### 회귀 분석이란?
#
#  [회귀분석](https://www.appier.com/ko-kr/blog/5-types-of-regression-analysis-and-when-to-use-them)은 데이터 분석에 사용되는 매우 강력한 머신러닝 도구이다.
#
# [회귀 분석](https://ko.wikipedia.org/wiki/%ED%9A%8C%EA%B7%80_%EB%B6%84%EC%84%9D)은 종속 변수(목표)와 독립 변수(예측 변수 라고도 함)간의 관계를 조사한다. 일반적으로 예측, 시계열 모델링 및 변수 간의 인과 관계를 찾을 때 사용한다.
#
# 예를 들어 난폭운전과 운전자에 의한 교통사고 총 건수 사이의 상관관계를 예측하거나 비즈니스 상황에서는 특정 금액을 광고에 사용했을 때와 그것이 판매에 미치는 영향 사이의 관계를 예측하는데 사용할 수 있다.
#
# 회귀분석 모델은 수치적 가치를 측정한다는 측면에서 관측치가 어느 범주에 속하는지를 식별하는 분류 모델과는 다르다.
#
# 다시 한번 언급하지만,<font color=red> 회귀분석은 예측, 시계열 모델링 및 변수 간 인과관계 발견 등에 주로 사용된다.</font>
#
# ### 회귀분석이 중요한 이유
#
# 회귀분석은 실제 응용 프로그램에서 넓게 활용되고 있다. 연속 숫자를 포함하는 모든 머신러닝 문제 해결에 필수적이며, 많은 예가 포함된다.
#
# - 금융 관련 예측(주택 가격 또는 주가)
# - 판매 및 프로모션 예측
# - 자동차 테스트
# - 날씨 분석 및 예측
# - 시계열 예측
#
# 회귀분석은 두 개 이상의 변수 사이에 유의미한 관계가 존재하는지 여부를 알려줄 뿐만 아니라 그 관계성에 대한 보다 구체적인 정보를 제공할 수 있다.
# 특히, 여러 변수가 종속 변수에 미치는 영향의 강도를 추정할 수 있다. 만약 한 변수(ex.가격)의 값을 변경하면 회귀분석을 통해 종속 변수(ex.판매)에 어떤 영향을 미칠 지 알 수 있다.
#
# 기업은 회귀분석을 사용하여 여러 척도로 측정된 변수의 효과를 검정할 수 있다. 활용할 수 있는 도구 상자에 회귀분석을 포함해두면, 예측 모델을 구축할 때 사용할 최상의 변수 집합을 평가하여 예측 정확도를 크게 높일 수 있다.
#
# 마지막으로 회귀분석은 데이터 모델링을 사용하여 머신러닝에서 회귀 문제를 해결하는 가장 좋은 방법이다. 차트에 데이터 포인터를 표시하고 이들을 관통하는 가장 적합한 선을 그어 각 데이터 포인트의 오류 가능성을 예측할 수 있다. 즉, 각 데이터 점이 선에서 멀리 떨어져 있을수록 예측 오차가 커진다.(가장 적합한 선을 회귀선이라고 부르기도 한다.)
#
# ### 회귀분석의 다양한 유형
#
# ### 1. 선형 회귀(Linear regression)
#
# 머신러닝에서 가장 일반적인 회귀분석 유형.
# 선형 회귀는 예측 변수와 종속 변수로 구성되며, 이 둘은 선형 방식으로 서로 연관지어져 있다.
# 선형 회귀는 위에서 설명한 대로 가장 적합한 선, 즉 최적적합선을 사용한다.
#
# 변수들이 서로 선형적으로 연결되어 있는 경우 선형 회귀를 사용한다. 광고 지출 증가가 판매에 미치는 영향을 예측할 때 등이 예가 될 수 있다. 그러나 선형 회귀분석은 특이치에 영향을 받기 쉬우므로 빅데이터 집합을 분석하는데 사용해서는 안 된다.
#
#
# ![image.png](data:image/png;base64,...)
# ### 2. 로지스틱 회귀(Logistic regression)
#
# 종속 변수에 이산 값이 있는 경우, 0 또는 1, 참 또는 거짓, 흑 또는 백 등 두 가지 값 중 하나만 취할 수 있는 경우 로지스틱 회귀를 사용하여 데이터를 분석 할 수 있다.
#
# 로지스틱 회귀는 S자형 곡선을 사용하여 대상 변수와 독립 변수 사이의 관계를 표시한다. 그러나 로지스틱 회귀 분석 방식은 대상 변수에서 거의 동일한 값이 발생하는 대규모 데이터 세트에서 가장 효과가 있다는 사실에 유의해야 한다.
# 이 경우, 변수들의 순위를 지정할 때 문제를 일으킬 수 있기 때문에 서로 상관성이 높은 독립 변수들이 데이터 집합에 포함되어서는 안 된다. (이것은 multicollinearity,즉 다중공선성이라고 알려진 현상으로, 회귀 분석에서 사용된 모델의 일부 예측 변수가 다른 예측 변수와 상관 정도가 높아, 데이터 분석 시 부정적인 영향을 미치는 현상을 의미함)
# ![image.png](data:image/png;base64,...)
# (출처: https://www.tibco.com/ko/reference-center/what-is-logistic-regression)
#
#
# ### 3. 리지 회귀(Ridge regression)
#
# 그러나, 불가피하게 독립 변수들 사이에 높은 상관 관계가 있는 경우라면 리지 회귀가 더 적합한 접근방식이다. 다중 회귀라고도 불리는 리지 회귀는 정규화 또는 규제화(regularization)기법으로 알려져 있으며 모델의 복잡성을 줄이는 데 사용된다. 또한 '리지 회귀 페널티'로 알려진 약간의 편향, 즉 바이어스(bias)를 사용하여 모델이 과대적합(overfitting)에 덜 취약하게 만든다.
#
#
# ### 4. 라쏘 회귀(Lasso regression)
#
# 라쏘 회귀는 리지 회귀와 같이 모델의 복잡성을 줄여주는 또 다른 정규화 기법이다. 회귀계수의 절대 사이즈를 금지함으로써 복잡성을 줄인다. 리지 회귀와는 다르게 아예 계수 값을 0에 가깝게 만든다.
#
# 그 장점은 기능 선택을 사용할 수 있다는 것이다. 데이터 집합에서 기능 세트를 선택하여 모델을 구축할 수 있다. 라쏘 회귀는 필요한 요소들만 사용하고 나머지를 0으로 설정함으로써 과대적합을 방지 할 수 있다.
#
# ![image.png](data:image/png;base64,...)
#
# (출처: https://zetawiki.com/wiki/%EB%9D%BC%EC%8F%98_%ED%9A%8C%EA%B7%80,_%EB%A6%AC%EC%A7%80_%ED%9A%8C%EA%B7%80)
#
# ### 5. 다항 회귀(Polynomial regression)
#
# 다 회귀는 선형 모델을 사용하여 비선형 데이터 집합을 모델링힌다. 이것은 동그란 모양의 구멍에 네모난 모양의 못 또는 말뚝을 끼워 넣는 것과 같다. 다항 회귀는 독립 변수가 여러 개인 선형 회귀를 뜻하는 다중 선형 회귀와 비슷한 방식으로 작동하지만, 비선형 곡선을 사용한다. 즉, 데이터 포인트가 비선형 방식으로 존재할 때 사용한다.
#
# 모델은 이 데이터 포인트들을 지정도니 수준의 다항식 특성으로 변환하고 선형 모델을 사용하여 모델화한다. 선형 회귀에서 볼 수 있는 직선이 아닌 곡선의 다항식 선을 사용하여 최적적합을 수행한다. 그러나 이 모델은 과대적합으로 나타나기 쉬우므로 이상한 결과치를 피하기 위해서는 끝 부분의 곡선을 분석하는 것이 좋다.
# ![image.png](data:image/png;base64,...)
#
# (출처: https://velog.io/@ckh0824/%EB%8B%A4%ED%95%AD-%ED%9A%8C%EA%B7%80)
#
#
# 참조: https://www.appier.com/ko-kr/blog/5-types-of-regression-analysis-and-when-to-use-them

# %% [markdown]
# ## 선형 회귀(Linear Regression)

# %% [markdown]
# 선형 회귀는 가장 일반적인 회귀 기법 중 하나이다. 직선을 사용하여 변수 간의 관계를 나타낸다.
#
# ### 회귀선
# 최적 적합선으로 알려진 회귀선은 선형 관계를 결정하는 데 사용된다. 우리가 비교하는 변수 간의 관계를 가장 잘 나타내는 선이다.
#
# 아래 그림에 표시된 직선을 y = mx + c의 방정식으로 설명 할 수 있다.
# - m: 선의 기울기
# - c: y절편
#
# ![concepts12.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 회귀 분석을 지원하기 위해 sklearn 라이브러리에는 LinearRegression() 함수 존재. 이 함수는 데이터를 사용하여 최적선이라고도 하는 선형 회귀선을 표시하거나 찾는다.
#
#
# 선형 회귀는 최소 제곱법을 사용하여 최적의 선을 구한다. 이는 y = mx + c의 방정식에서 m과 c를 구하는 것을 의미한다. 이 경우 실제 값과 예측 값의 간의 차이에 대한 제곱의 최소 합을 구한다.
#
# https://www.youtube.com/watch?v=JvS2triCgOY

# %% [markdown]
# ## 회귀 문제를 해결하기 위한 단계별 접근
#
# - 변수를 산점도에 그려서 변수 간의 관계를 알 수 있다.
# - 선을 사용하여 그들 사이의 관계를 나타낼 수 있다.
# - 선형 회귀에서 변수 간의 관계를 나타내기 위해 직선을 사용한다.
# - 최적선은 변수 간의 선형관계를 나타내는 최적선으로 간주된다.
#
# 회귀분석을 수행해보장

# %% [markdown]
# ### 1:라이브러리 가져오기
# 먼저 pandas,matplotlib,numpy 및 seaborn 라이브러리를 가져온다.
# - pandas와 numpy는 데이터를 구성하고 조작하는데 필요
# - matplotlib 및 seaborn은 데이터를 그래프 형태로 시각화하는데 필요

# %%
# 라이브러리 가져오기

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2: csv 데이터 읽기
#
# weatherHistory 파일에서 csv 데이터를 읽고 각 특성(features)의 데이터 유형을 살펴보자.

# %%
# csv 파일 읽기

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/review/18/weatherHistory.csv")

# 처음 10개 값 출력
print(data.head(10))
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6  2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7  2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8  2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9  2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# ### 3: 데이터 유형 알아보기

# %%
# 특성 데이터 타입 출력
print(data.dtypes)
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %% [markdown]
# ### 4: 그래프를 그려서 여러 변수들 간의 잠재적인 관계를 살펴보자!
#
# 1. 압력 대 시간
# 2. 습도 대 시간
# 3. 온도 대 시간
#
#
# 그래프를 그리기 전에 먼저 0과 NaN값 데이터를 정리한다.

# %%
# DataFrame의 0을 NaN으로 변경

data = data.replace(0,np.nan)

# %%
# DataFrame의 컬럼별 NaN값의 개수 알아보기

data.isnull().sum()
# Out:
# Formatted Date                  0
# Summary                         0
# Precip Type                   517
# Temperature (C)               325
# Apparent Temperature (C)       69
# Humidity                       22
# Wind Speed (km/h)            1297
# Wind Bearing (degrees)       2264
# Visibility (km)               450
# Loud Cover                  96453
# Pressure (millibars)         1288
# Daily Summary                   0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 102685

# %%
data.dropna(axis=1)
# Out:
#                       Formatted Date        Summary  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy
# ...                              ...            ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy
#
#                                 Daily Summary
# 0           Partly cloudy throughout the day.
# 1           Partly cloudy throughout the day.
# 2           Partly cloudy throughout the day.
# 3           Partly cloudy throughout the day.
# 4           Partly cloudy throughout the day.
# ...                                       ...
# ...

# %%
data.isnull().sum()
# Out:
# Formatted Date                  0
# Summary                         0
# Precip Type                   517
# Temperature (C)               325
# Apparent Temperature (C)       69
# Humidity                       22
# Wind Speed (km/h)            1297
# Wind Bearing (degrees)       2264
# Visibility (km)               450
# Loud Cover                  96453
# Pressure (millibars)         1288
# Daily Summary                   0
# dtype: int64

# %%
# 온도 대 습도

pressure = data['Pressure (millibars)']
humidity = data['Humidity']
temperature = data['Temperature (C)']

plt.figure(figsize=(10,10))
ax = sns.scatterplot(x=temperature, y=humidity)
plt.show()

# %% [markdown]
# ### 압력 vs 습도

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x=pressure, y=humidity)
plt.show()

# %% [markdown]
# ### 압력 vs 온도

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x=pressure,y=temperature)
plt.show()

# %% [markdown]
# 산점도에서는 변수 간의 상관 관계를 알기 어렵다.

# %% [markdown]
# ### 5: 히트맵으로 상관 관계 시각화

# %%
import seaborn as sns
snsplot = sns.heatmap(data.corr(), annot=True, linewidths=0.5, fmt = '.1f')
#snsplot.figure.savefig("corr_data.png")

plt.show()

# %% [markdown]
# data.corr()은 열의 쌍별 상관 관계를 계산하여 상관 계수를 제공한다. 1 또는 -1에 가까울 수록 두 변수의 상관 관계가 높아짐!

# %% [markdown]
# ### 6:
# 어떤 변수가 서로 더 상관관계가 있는가?
#
# - 온도 대 습도
# - Apparent Temperature vs Humidity

# %%
import datetime
# 날짜 열을 변환하기 위한 호출

data['Formatted Date'] = pd.to_datetime(data['Formatted Date'],
                                        format='%Y-%m-%d %H:%M:%S.%f', utc=True)
data = data.drop("Loud Cover", axis = 1)
data = data.dropna()

# 날짜 열이 날짜,시간 형식인지 확인
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91983 entries, 0 to 96452
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            91983 non-null  datetime64[ns, UTC]
#  1   Summary                   91983 non-null  object
#  2   Precip Type               91983 non-null  object
#  3   Temperature (C)           91983 non-null  float64
#  4   Apparent Temperature (C)  91983 non-null  float64
#  5   Humidity                  91983 non-null  float64
#  6   Wind Speed (km/h)         91983 non-null  float64
#  7   Wind Bearing (degrees)    91983 non-null  float64
#  8   Visibility (km)           91983 non-null  float64
#  9   Pressure (millibars)      91983 non-null  float64
#  10  Daily Summary             91983 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(7), object(3)
# memory usage: 8.4+ MB
# None

# %%
data.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                   251.0          15.8263               1015.13
# ...

# %%
print(data['Formatted Date'][10].month)
# Out:
# 4

# %%
print(data['Formatted Date'][0].day)
print(data['Formatted Date'][0].month)
print(data['Formatted Date'][0].year)
# Out:
# 31
# 3
# 2006

# %%
# 기존 data에 month열 추가

data['month'] = data['Formatted Date'].dt.month

# %%
data.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                   251.0          15.8263               1015.13
# ...

# %%
# 월별로 데이터 나누기

data_jan = data[data.month == 1]
data_feb = data[data.month == 2]
data_mar = data[data.month == 3]
data_apr = data[data.month == 4]
data_may = data[data.month == 5]
data_jun = data[data.month == 6]
data_jul = data[data.month == 7]
data_aug = data[data.month == 8]
data_sep = data[data.month == 9]
data_oct = data[data.month == 10]
data_nov = data[data.month == 11]
data_dec = data[data.month == 12]

# %% [markdown]
# ## 데이터 분석을 위해 1월 데이터 사용

# %%
snsplot = sns.heatmap(data_jan.corr(), annot=True,linewidths=0.5, fmt='.1f') # annot을 이용해 각 cell의 값을 표기 할 수 있다. 
#snsplot.figure.savefig("corr_data.png")

plt.show()

# %% [markdown]
# ## 데이터 분석을 위해 2월 데이터 사용

# %%
snsplot = sns.heatmap(data_feb.corr(), annot=True, linewidths=0.5, fmt='.1f')

plt.show()

# %% [markdown]
# ## 데이터 분석을 위해 3월 데이터 사용

# %%
snsplot = sns.heatmap(data_mar.corr(), annot=True, linewidths=0.5, fmt='.1f')

plt.show()

# %% [markdown]
# ## 데이터 분석을 위해 4월 데이터 사용

# %%
snsplot = sns.heatmap(data_apr.corr(), annot = True, linewidths=0.5, fmt='.1f')

plt.show()

# %% [markdown]
# ## 데이터 분석을 위해 5월 데이터 사용

# %%
snsplot = sns.heatmap(data_may.corr(), annot=True, linewidths=0.5, fmt='.1f')

plt.show()

# %% [markdown]
# ## 데이터 분석을 위해 8월 데이터 사용

# %%
snsplot = sns.heatmap(data_aug.corr(),annot=True, linewidths=0.5, fmt='.1f')

plt.show()

# %% [markdown]
# ## 데이터 분석을 위해 9월 데이터 사용

# %%
snsplot = sns.heatmap(data_sep.corr(), annot=True, linewidths=0.5, fmt='.1f')

plt.show()

# %% [markdown]
# ## 데이터 분석을 위해 10월 데이터 사용

# %%
snsplot = sns.heatmap(data_oct.corr(), annot=True, fmt='.1f')
plt.show()

# %% [markdown]
# ### 관계의 산점도 그리기

# %%
# 9월

pressure_sep = data_sep['Pressure (millibars)']
humidity_sep = data_sep['Humidity']
temperature_sep = data_sep['Temperature (C)']

# %%
plt.figure(figsize = (10,10))
ax = sns.scatterplot(x=temperature_sep, y=humidity_sep)
plt.show()

# %% [markdown]
# 전체 데이터 산점도에 비해 더 선형적인 경향을 보임.

# %% [markdown]
# ### scikit learn 라이브러리를 사용한 회귀 분석
#
# 기계 학습을 통해 우리는 선택한 특성과 대상 변수 사이의 관계를 설명할 수 있는 가장 적합한 선을 결정할 것이다.
#
# 데이터를 예측하기 전에 sklearn 라이브러리에서 가져와야 하는 몇 가지 사항이 있다.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# 회귀 모델의 특성과 대상을 설정

# %%
features_available = [
    'Temperature (C)',
]
X = data[features_available]
y = data['Humidity']

# %% [markdown]
# ### 8:
# 위의 코드에서 무엇이 종속 변수이고 독립 변수인가?'
#
# 종속 변수: 습도
# 독립 변수: 온도

# %% [markdown]
# ### 데이터를 훈련 세트와 테스트 세트로 나누기
#
# 이제 테스트 세트와 훈련 세트로 데이터를 나눈다.
# 지도 학습 문제에서 학습 기능을 위해 훈련 데이터 세트를 제공해야 한다. 그런 다음 훈련 세트를 기반으로 모델을 생성한다.
# 테스트 세트는 모델의 성능을 확인하기 위해 모델의 예측 값을 테스트하는 데 사용
#
# https://towardsdatascience.com/train-test-split-and-cross-validation-in-python-80b61beca4b6 을 참조
#
# train_test_split 함수를 호출하여 코드를 구현.
# 훈련 세트의 데이터를 70%, 테스트 세트의 데이터를 30%로 분할

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %% [markdown]
# 변수의 모양을 출력하여 테스트 세트가 총 데이터의 0.3이고 훈련 세트가 총 데이터의 0.7인지 확인하는 코드를 작성

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (64388, 1)
# (27595, 1)
# (64388,)
# (27595,)

# %% [markdown]
# ### 선형 회귀 객체 생성
#
# sickit learn에서 가져온 Linear Regression 클래스 이용하여 선형 회귀 객객체 생성

# %%
linreg = LinearRegression()

# %% [markdown]
# fit 함수를 이용하여 데이터 세트를 설명하는 가장 좋은 선 찾기. 훈련 데이터 세트를 사용한 모델 훈련이다.
#
# 훈련 세트를 사용하여 데이터를 피팅하고 테스트 세트를 사용하여 예측하는 단계
#
# 그 다음 mean_absolute_error를 사용하여 모델의 효율성을 테스트하여 테스트와 예측 값이 얼마나 차이 나는지 확인

# %%
linreg.fit(X_train,y_train) #선형 회귀 모델 훈련
# Out:
# LinearRegression()

# %% [markdown]
# 훈련 후 선의 절편과 기울기를 출력 할 수 있다.

# %%
# y절편 출력:
print(linreg.intercept_)
# 기울기 출력:
print(linreg.coef_)
# Out:
# 0.8910284729045763
# [-0.01310752]

# %% [markdown]
# 모델을 학습했으므로 몇 가지 예측 가능

# %%
y_pred = linreg.predict(X_test)

# %% [markdown]
# 이제 습도의 실제 값과 예측 값을 비교하는 데이터 프레임을 만들 수 있다.

# %%
df = pd.DataFrame(columns=['Actual','Predicted'])

# %%
df['Actual'] = y_test
df['Predicted'] = y_pred

# %%
df
# Out:
#        Actual  Predicted
# 29382    0.92   0.905592
# 35704    0.64   0.698275
# 56743    0.85   0.595090
# 72864    0.88   0.942366
# 78707    0.38   0.600114
# ...       ...        ...
# 24433    0.77   0.847555
# 57527    0.55   0.577322
# 55906    0.93   0.839399
# 25983    0.48   0.665579
# 95798    0.35   0.492196
#
# [27595 rows x 2 columns]

# %% [markdown]
# 다음으로 그래프를 그려 최적의 선으로 데이터 세트를 표시한다.

# %%
plt.scatter(X_test, y_test, color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# ### 모델 평가
#
# 최적의 라인을 평가하기 위한 다양한 방법이 있다
# 선형 회귀 문제에 대해 사용하는 일반적인 세가지 측정 지표는 MAE(Mean Absolut Error),MSE(Mean Squared Error), R2 Score 가 있다.
#
#
# 1. MAE(Mean Absolute Error): 평균절대오차
# ![image.png](data:image/png;base64,...)
# - 모델의 예측값과 실제값의 차이를 모두 더하는 개념
# - 절대값을 취하기 때문에 직관적으로 알 수 있는 지표
# - MSE보다 특이치에 robust하다. (특이치에 영향을 많이 안 받는다는 의미)
# - MAE는 절대값을 취하는 지표이기에 실제보다 낮은 값인지 큰 값인지 알 수 없다.
#
# ![image.png](data:image/png;base64,...)
#
#
# 2. MSE(Mean Squared Error): 평균제곱오차
# ![image.png](data:image/png;base64,...)
# - MAE와 다르게 제곱을 하기 때문에 모델의 실제값과 예측값 차이의 면적의 합이다.
# - 제곱을 하기 때문에 특이값이 존재하면 수치가 많이 늘어난다.(=특이치에 민감함)
# ![image.png](data:image/png;base64,...)
#
# 출처:https://whiplash-bd.tistory.com/45
#
# 3. R2 score(결정계수)
# - 결정계수는 상관계수를 제곱한 값으로 보면 된다. 하지만 결저계수는 상관계수와 달리 변수간 영향을 주는 정도 또는 인과 관계의 정도를 정량화해서 나타낸 수치이다. 따라서 결정계수는 상관 분석이 아닌 회귀분석에서 사용하는 수치이다.
# - R2 score(R-squared)는 회귀 모델의 성능에 대한 평가지표이며, 회귀모델에서 독립 변수가 종속 변수를 얼마나 잘 설명해주는 지 보여주는 지표이다. 하지만 독립변수의 개수가 증가하면 결정계수 또한 함께 증가하여 결정계수에만 의존하여 회귀 모델을 평가하기 어렵다. 그래서 조정된 결정계수(adjusted R-squared)가 제시되었다.
# ![image.png](data:image/png;base64,...)
# 여기서 SST는 총 제곱합, SSE는 회귀식 추정값과 관측값의 평균 간 차이인 회귀 제곱합을 나타낸다.
# SSR은 잔차 제곱합이다.
# ![image.png](data:image/png;base64,...)
#
# R2 = 1: 좋은 회귀 모델
# R2 = 0: 나쁜 모델
# R2 < 0(음수): 쓰레기 모델 or 임의의 데이터를 이용한 경우
#
#
#
# 참조: https://velog.io/@parkchansaem/R2-score%EA%B2%B0%EC%A0%95%EA%B3%84%EC%88%98

# %%
, median_absolute_error
print("Linear Regression Score")
predict = linreg.predict(X_test)
print("Mean Absolute Error: ", mean_absolute_error(y_test,y_pred))
print("Mean Squared Error: ", mean_squared_error(y_test,y_pred))
print("R2: ", r2_score(y_test,y_pred))
# Out:
# Linear Regression Score
# Mean Absolute Error:  0.12165860262865213
# Mean Squared Error:  0.022679545798067583
# R2:  0.4120669601124197

# %% [markdown]
# 초기 데이터 세트는 특정 경향이나 상관 관계를 가지지 않았기 때문에 모델의 성능이 다소 떨어진다.
# 월간 데이터를 사용하여 습도와 온도라는 두 변수 사이의 관계를 표시해보자.

# %% [markdown]
# ### 9월 데이터를 사용하여 선형 회귀 모델 훈련하기

# %% [markdown]
# ### 특성을 선택

# %%
features_available = [
    'Temperature (C)', 
]
X = data_sep[features_available]
y = data_sep['Humidity']

# %% [markdown]
# ### 데이터를 분할 합니다.

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5284, 1)
# (2265, 1)
# (5284,)
# (2265,)

# %% [markdown]
# ### 선형 회귀 인스턴스(instance)를 생성합니다.

# %%
linreg = LinearRegression()

# %% [markdown]
# ### 모델을 학습시킵니다.

# %%
linreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 절편과 기울기를 출력합니다.

# %%
# 절편 출력:
print(linreg.intercept_)
# 기울기 출력:
print(linreg.coef_)
# Out:
# 1.1712436551649845
# [-0.02759216]

# %% [markdown]
# ### 테스트 데이터를 사용하여 예측합니다.

# %%
y_pred = linreg.predict(X_test)

# %% [markdown]
# ### 데이터 프레임을 사용하여 실제 값과 예측 값 비교합니다.

# %%
df = pd.DataFrame(columns=['Actual','Predicted'])

df['Actual'] = y_test
df['Predicted'] = y_pred

# %%
df
# Out:
#        Actual  Predicted
# 51987    0.78   0.714287
# 87481    0.79   0.684702
# 69599    0.85   0.745251
# 25835    0.83   0.895629
# 52340    0.62   0.681636
# ...       ...        ...
# 26153    0.34   0.346698
# 52044    0.61   0.540150
# 43539    0.77   0.805341
# 34948    0.73   0.588742
# 34488    0.81   0.711374
#
# [2265 rows x 2 columns]

# %% [markdown]
# ### 그래프를 그립니다.

# %%
plt.scatter(X_test, y_test, color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# 최적의 선이 데이터 세트에 더 가깝기 때문에 온도 기반 습도 값을 더 잘 예측할 수 있을 것 같다.

# %% [markdown]
# ### 성능 지표를 출력하세요

# %%
print ("Linear Regression Score")
predict = linreg.predict(X_test)
print ("Mean Absolute Error: ", mean_absolute_error(y_test,y_pred))
print ("Mean Squared Error: ", mean_squared_error(y_test,y_pred))
print ("R2: ", r2_score(y_test,y_pred))
# Out:
# Linear Regression Score
# Mean Absolute Error:  0.10539735327675859
# Mean Squared Error:  0.016734406159362357
# R2:  0.6038898727853304

# %% [markdown]
# 성능이 아까보다 좋아졌다!
